# %%
# !ls /net/pulsar/home/koes/jok120/scnmin220915/min/1A9*
# pmin = SCNProtein.from_pkl("/net/pulsar/home/koes/jok120/scnmin220915/min/1A92_1_A.pkl")
# pmin.to_3Dmol()
# p = SCNProtein.from_pkl(path)
# p.to_3Dmol()

# %%
import sidechainnet as scn
from sidechainnet.utils.minimize_scn import SCNProtein.from_pkl
from sidechainnet.utils.minimizer import SCNMinimizer

# %%
path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1A92_1_A.pkl"      # med/small protein
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1B0M_1_A.pkl"        # large protein
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1R27_d1r27c2.pkl"  # large protein

# %% [markdown]
# # 100 Total Steps, LR = 1e-4

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=20,
                            max_eval=20,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# Epoch 0:	4334.41
# Epoch 0: Loss has been updated.  tensor(4334.411, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	3879.30
# Epoch 1: Loss has been updated.  tensor(3879.300, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	3521.91
# Epoch 2: Loss has been updated.  tensor(3521.908, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	3437.40
# Epoch 3: Loss has been updated.  tensor(3437.396, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	3332.14
# Epoch 4: Loss has been updated.  tensor(3332.144, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 5:	3260.13
# Epoch 5: Loss has been updated.  tensor(3260.127, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 6:	3159.13
# Epoch 6: Loss has been updated.  tensor(3159.130, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 7:	3097.12
# ...

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# Epoch 0:	3437.84
# Epoch 0: Loss has been updated.  tensor(3437.835, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	3097.36
# Epoch 1: Loss has been updated.  tensor(3097.359, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2804.88
# Epoch 2: Loss has been updated.  tensor(2804.876, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	2538.94
# Epoch 3: Loss has been updated.  tensor(2538.939, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	2283.63
# Epoch 4: Loss has been updated.  tensor(2283.631, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 5:	2033.00
# Epoch 5: Loss has been updated.  tensor(2033.001, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 6:	1785.28
# Epoch 6: Loss has been updated.  tensor(1785.284, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 7:	1502.38
# ...

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# Epoch 0:	3437.78
# Epoch 0: Loss has been updated.  tensor(3437.780, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	3097.39
# Epoch 1: Loss has been updated.  tensor(3097.387, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2805.67
# Epoch 2: Loss has been updated.  tensor(2805.668, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	2539.14
# Epoch 3: Loss has been updated.  tensor(2539.144, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	2284.75
# Epoch 4: Loss has been updated.  tensor(2284.752, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 5:	2035.32
# Epoch 5: Loss has been updated.  tensor(2035.316, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 6:	1788.54
# Epoch 6: Loss has been updated.  tensor(1788.543, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 7:	1548.70
# ...

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=500,
                            max_eval=500,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# Epoch 0:	2283.92
# Epoch 0: Loss has been updated.  tensor(2283.922, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	1046.44
# Epoch 1: Loss has been updated.  tensor(1046.435, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	218.36
# Epoch 2: Loss has been updated.  tensor(218.361, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	-306.93
# Epoch 3: Loss has been updated.  tensor(-306.928, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	-687.02
# Epoch 4: Loss has been updated.  tensor(-687.022, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 5:	-1018.86
# Epoch 5: Loss has been updated.  tensor(-1018.863, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 6:	-1290.53
# Epoch 6: Loss has been updated.  tensor(-1290.526, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 7:	-1567.52
# ...

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=400,
                            max_eval=400,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# Epoch 0:	-102.41
# Epoch 0: Loss has been updated.  tensor(-102.411, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)

# %% [markdown]
# # 5000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=1000,
                            max_eval=1000,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=5000,
                            max_eval=5000,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # Repeating the above with a larger starting learning rate

# %% [markdown]
# # 100 Total Steps, LR = 1e-3

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=20,
                            max_eval=20,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3, in <module>
#
# File ~/repos/sidechainnet/sidechainnet/utils/minimizer.py:169, in SCNMinimizer.minimize_scnprotein(self, p, use_sgd, verbose, path, starting_lr, max_iter, epochs, lr_decay, max_eval, patience)
#     167     opt.step()
#     168 else:
# --> 169     opt.step(closure)
#     170     # Early Stopping and Loss Evaluation
#     171     loss = energy_loss.apply(p, p.hcoords)
#
# File ~/anaconda3/envs/sidechainnetv2/lib/python3.8/site-packages/torch/optim/optimizer.py:88, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#      86 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87 with torch.autograd.profiler.record_function(profile_name):
# ---> 88     return func(*args, **kwargs)
#
# ...

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27
# KeyboardInterrupt

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=500,
                            max_eval=500,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=100,
                            lr_decay=True, patience=3)
# Out:
# Starting loss = 5429.27

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=400,
                            max_eval=400,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # Trying with a larger protein

# %%
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1A92_1_A.pkl"      # med/small protein
path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1B0M_1_A.pkl"        # large protein
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1R27_d1r27c2.pkl"  # large protein

# %% [markdown]
# # 100 Total Steps, LR = 1e-4

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=20,
                            max_eval=20,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=500,
                            max_eval=500,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=400,
                            max_eval=400,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # Repeating the above with a larger starting learning rate

# %% [markdown]
# # 100 Total Steps, LR = 1e-3

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=20,
                            max_eval=20,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=500,
                            max_eval=500,
                            epochs=100,
                            lr_decay=True, patience=3)

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=400,
                            max_eval=400,
                            epochs=100,
                            lr_decay=True, patience=3)

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=100,
                            lr_decay=True, patience=3)
