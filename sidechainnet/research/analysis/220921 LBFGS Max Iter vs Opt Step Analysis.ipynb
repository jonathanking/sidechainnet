# %%
# !ls /net/pulsar/home/koes/jok120/scnmin220915/min/1A9*
# pmin = SCNProtein.from_pkl("/net/pulsar/home/koes/jok120/scnmin220915/min/1A92_1_A.pkl")
# pmin.to_3Dmol()
# p = SCNProtein.from_pkl(path)
# p.to_3Dmol()

# %%
import sidechainnet as scn
from sidechainnet.utils.minimize_scn import SCNProtein.from_pkl
from sidechainnet.utils.minimizer import SCNMinimizer

# %%
path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1A92_1_A.pkl"      # med/small protein
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1B0M_1_A.pkl"        # large protein
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1R27_d1r27c2.pkl"  # large protein

# %% [markdown]
# # 100 Total Steps, LR = 1e-4

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=20,
                            max_eval=20,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	4334.41
# Epoch 0: Loss has been updated.  tensor(4334.411, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	3879.30
# Epoch 1: Loss has been updated.  tensor(3879.296, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	3521.92
# Epoch 2: Loss has been updated.  tensor(3521.918, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	3437.39
# Epoch 3: Loss has been updated.  tensor(3437.388, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	3332.14
# Epoch 4: Loss has been updated.  tensor(3332.139, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 3332.14
# CPU times: user 4min 18s, sys: 15.9 s, total: 4min 34s
# Wall time: 10.7 s

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	3437.64
# Epoch 0: Loss has been updated.  tensor(3437.639, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 3437.64
# CPU times: user 3min 13s, sys: 11 s, total: 3min 24s
# Wall time: 8.03 s

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	3437.75
# Epoch 0: Loss has been updated.  tensor(3437.752, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	3097.33
# Epoch 1: Loss has been updated.  tensor(3097.330, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2805.29
# Epoch 2: Loss has been updated.  tensor(2805.291, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	2540.48
# Epoch 3: Loss has been updated.  tensor(2540.478, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	2284.92
# Epoch 4: Loss has been updated.  tensor(2284.918, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 2284.92
# CPU times: user 15min 27s, sys: 52.1 s, total: 16min 20s
# Wall time: 37.2 s

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=500,
                            max_eval=500,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	2285.96
# Epoch 0: Loss has been updated.  tensor(2285.957, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 2285.96
# CPU times: user 15min 7s, sys: 53 s, total: 16min
# Wall time: 37.1 s

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=400,
                            max_eval=400,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	2538.79
# Epoch 0: Loss has been updated.  tensor(2538.793, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	1546.66
# Epoch 1: Loss has been updated.  tensor(1546.663, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	613.07
# Epoch 2: Loss has been updated.  tensor(613.071, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	88.08
# Epoch 3: Loss has been updated.  tensor(88.080, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	-343.27
# Epoch 4: Loss has been updated.  tensor(-343.271, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = -343.27
# CPU times: user 1h 48s, sys: 3min 31s, total: 1h 4min 20s
# Wall time: 2min 29s

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	51.81
# Epoch 0: Loss has been updated.  tensor(51.812, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 51.81
# CPU times: user 1h 1min 9s, sys: 3min 29s, total: 1h 4min 38s
# Wall time: 2min 28s

# %% [markdown]
# # 5000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=1000,
                            max_eval=1000,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	1129.51
# Epoch 0: Loss has been updated.  tensor(1129.513, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	-307.04
# Epoch 1: Loss has been updated.  tensor(-307.035, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	-1037.20
# Epoch 2: Loss has been updated.  tensor(-1037.198, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	-1760.61
# Epoch 3: Loss has been updated.  tensor(-1760.611, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	-2496.84
# Epoch 4: Loss has been updated.  tensor(-2496.835, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = -2496.84
# CPU times: user 2h 29min 56s, sys: 8min 33s, total: 2h 38min 29s
# Wall time: 6min 7s

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=5000,
                            max_eval=5000,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	-2090.02
# Epoch 0: Loss has been updated.  tensor(-2090.023, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = -2090.02
# CPU times: user 2h 31min 49s, sys: 8min 37s, total: 2h 40min 26s
# Wall time: 6min 7s

# %% [markdown]
# # Repeating the above with a larger starting learning rate

# %% [markdown]
# # 100 Total Steps, LR = 1e-3

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=20,
                            max_eval=20,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	4350.57
# Epoch 0: Loss has been updated.  tensor(4350.574, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	3697.94
# Epoch 1: Loss has been updated.  tensor(3697.939, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	3545.84
# Epoch 2: Loss has been updated.  tensor(3545.841, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	3336.29
# Epoch 3: Loss has been updated.  tensor(3336.293, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	3252.77
# Epoch 4: Loss has been updated.  tensor(3252.771, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 3252.77
# CPU times: user 4min 21s, sys: 15.1 s, total: 4min 36s
# Wall time: 10.7 s

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	3336.28
# Epoch 0: Loss has been updated.  tensor(3336.282, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 3336.28
# CPU times: user 3min 16s, sys: 11.2 s, total: 3min 27s
# Wall time: 8.2 s

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	3336.28
# Epoch 0: Loss has been updated.  tensor(3336.280, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	2800.46
# Epoch 1: Loss has been updated.  tensor(2800.459, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2341.42
# Epoch 2: Loss has been updated.  tensor(2341.425, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	1912.55
# Epoch 3: Loss has been updated.  tensor(1912.554, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	1502.12
# Epoch 4: Loss has been updated.  tensor(1502.122, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 1502.12
# CPU times: user 16min 38s, sys: 55.7 s, total: 17min 34s
# Wall time: 40.4 s

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=500,
                            max_eval=500,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	1503.59
# Epoch 0: Loss has been updated.  tensor(1503.587, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 1503.59
# CPU times: user 16min 4s, sys: 54.9 s, total: 16min 59s
# Wall time: 39.2 s

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=400,
                            max_eval=400,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = -3087.55
# Epoch 0:	-4170.72
# Epoch 0: Loss has been updated.  tensor(-4170.723, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	-5093.91
# Epoch 1: Loss has been updated.  tensor(-5093.905, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	-5822.61
# Epoch 2: Loss has been updated.  tensor(-5822.606, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	-6413.60
# Epoch 3: Loss has been updated.  tensor(-6413.598, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	-6898.95
# Epoch 4: Loss has been updated.  tensor(-6898.953, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = -6898.95
# CPU times: user 1h 1min 46s, sys: 3min 32s, total: 1h 5min 18s
# Wall time: 2min 30s

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 5429.27
# Epoch 0:	-3087.55
# Epoch 0: Loss has been updated.  tensor(-3087.554, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = -3087.55
# CPU times: user 1h 31s, sys: 3min 26s, total: 1h 3min 57s
# Wall time: 2min 27s

# %% [markdown]
# # Trying with a larger protein

# %%
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1A92_1_A.pkl"      # med/small protein
path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1B0M_1_A.pkl"        # large protein
# path = "/net/pulsar/home/koes/jok120/scnmin220905/unmin/1R27_d1r27c2.pkl"  # large protein

# %% [markdown]
# # 100 Total Steps, LR = 1e-4

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=20,
                            max_eval=20,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.65
# Epoch 0:	117390179696169552.00
# Final loss = 117390179696169552.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.54
# Epoch 0:	40539701173.53
# Epoch 0: Loss has been updated.  tensor(40539701173.532, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	79771039133.69
# Epoch 2:	677336139.98
# Epoch 2: Loss has been updated.  tensor(677336139.980, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	27628010.72
# Epoch 3: Loss has been updated.  tensor(27628010.722, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	670078757382.77
# Final loss = 670078757382.77
# CPU times: user 2h 5min 42s, sys: 1min 15s, total: 2h 6min 58s
# Wall time: 2min 57s

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.62
# Epoch 0:	5087271015723521.00
# Final loss = 5087271015723521.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.64
# Epoch 0:	27628010.72
# Epoch 0: Loss has been updated.  tensor(27628010.722, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 27628010.72
# CPU times: user 2h 18min 16s, sys: 1min 46s, total: 2h 20min 2s
# Wall time: 3min 18s

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=100,
                            max_eval=100,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.60
# Epoch 0:	5087270609234310.00
# Final loss = 5087270609234310.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.65
# Epoch 0:	27628010.72
# Epoch 0: Loss has been updated.  tensor(27628010.722, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	11250006.00
# Epoch 1: Loss has been updated.  tensor(11250005.996, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2076592.94
# Epoch 2: Loss has been updated.  tensor(2076592.937, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	1365351.56
# Epoch 3: Loss has been updated.  tensor(1365351.560, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	989810.25
# Epoch 4: Loss has been updated.  tensor(989810.247, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 989810.25
# CPU times: user 5h 46min 52s, sys: 5min 23s, total: 5h 52min 15s
# Wall time: 8min 52s

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=500,
                            max_eval=500,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.59
# Epoch 0:	8162234587928.49
# Final loss = 8162234587928.49
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.61
# Epoch 0:	989828.98
# Epoch 0: Loss has been updated.  tensor(989828.984, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 989828.98
# CPU times: user 10h 8min 41s, sys: 8min 43s, total: 10h 17min 24s
# Wall time: 15min 13s

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=400,
                            max_eval=400,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.60
# Epoch 0:	626831937831723.88
# Final loss = 626831937831723.88
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.61
# Epoch 0:	1365351.56
# Epoch 0: Loss has been updated.  tensor(1365351.560, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	976904.00
# Epoch 1: Loss has been updated.  tensor(976903.997, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	1220096656687.03
# Epoch 3:	2681287719884434.00
# Final loss = 2681287719884434.00
# The protein was not minimized correctly. Lowering LR  to 1.0000000000000002e-06 and trying again.
# Starting loss = 1860838086580.64
# Epoch 0:	2918217.64
# Epoch 0: Loss has been updated.  tensor(2918217.636, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	956968.08
# Epoch 1: Loss has been updated.  tensor(956968.078, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	852272.37
# Epoch 2: Loss has been updated.  tensor(852272.370, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	824737.67
# Epoch 3: Loss has been updated.  tensor(824737.672, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	803530.97
# Epoch 4: Loss has been updated.  tensor(803530.974, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 803530.97
# CPU times: user 2d 3h 59min 25s, sys: 31min 27s, total: 2d 4h 30min 53s
# Wall time: 1h 11min 23s

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-4,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.61
# Epoch 0:	242669217245450080.00
# Final loss = 242669217245450080.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.62
# Epoch 0:	68731533294941.92
# Final loss = 68731533294941.92
# The protein was not minimized correctly. Lowering LR  to 1.0000000000000002e-06 and trying again.
# Starting loss = 1860838086580.68
# Epoch 0:	805884.82
# Epoch 0: Loss has been updated.  tensor(805884.821, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 805884.82
# CPU times: user 3d 1h 14min 55s, sys: 46min 36s, total: 3d 2h 1min 31s
# Wall time: 1h 40min 40s

# %% [markdown]
# # Repeating the above with a larger starting learning rate

# %% [markdown]
# # 100 Total Steps, LR = 1e-3

# %%
# %%time
minimizer = SCNMinimizer()
p = SCNProtein.from_pkl(path)
loss1, ang1 = minimizer.minimize_scnprotein(p,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=20,
                            max_eval=20,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.64
# Epoch 0:	3740806537485214.50
# Final loss = 3740806537485214.50
# The protein was not minimized correctly. Lowering LR  to 0.0001 and trying again.
# Starting loss = 1860838086580.61
# Epoch 0:	117390179696177120.00
# Final loss = 117390179696177120.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.63
# Epoch 0:	40539701173.53
# Epoch 0: Loss has been updated.  tensor(40539701173.531, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	79771039133.69
# Epoch 2:	677336139.98
# Epoch 2: Loss has been updated.  tensor(677336139.980, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	27628010.72
# Epoch 3: Loss has been updated.  tensor(27628010.722, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	670078757382.78
# Final loss = 670078757382.78
# CPU times: user 2h 29min 38s, sys: 1min 28s, total: 2h 31min 6s
# Wall time: 3min 27s

# %%
# %%time
minimizer = SCNMinimizer()
p2 = SCNProtein.from_pkl(path)
loss2, ang2 = minimizer.minimize_scnprotein(p2,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.66
# Epoch 0:	693298473609911.50
# Final loss = 693298473609911.50
# The protein was not minimized correctly. Lowering LR  to 0.0001 and trying again.
# Starting loss = 1860838086580.63
# Epoch 0:	5087270789541857.00
# Final loss = 5087270789541857.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.59
# Epoch 0:	27628010.72
# Epoch 0: Loss has been updated.  tensor(27628010.722, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 27628010.72
# CPU times: user 3h 13min 6s, sys: 2min 36s, total: 3h 15min 43s
# Wall time: 4min 26s

# %% [markdown]
# # 500 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p3 = SCNProtein.from_pkl(path)
loss3, ang3 = minimizer.minimize_scnprotein(p3,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=100,
                            max_eval=100,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.57
# Epoch 0:	14207614835214894.00
# Final loss = 14207614835214894.00
# The protein was not minimized correctly. Lowering LR  to 0.0001 and trying again.
# Starting loss = 1860838086580.55
# Epoch 0:	5087270885998587.00
# Final loss = 5087270885998587.00
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.63
# Epoch 0:	27628010.72
# Epoch 0: Loss has been updated.  tensor(27628010.723, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	11250006.00
# Epoch 1: Loss has been updated.  tensor(11250005.997, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2076592.94
# Epoch 2: Loss has been updated.  tensor(2076592.937, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 3:	1365351.56
# Epoch 3: Loss has been updated.  tensor(1365351.561, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	989810.25
# Epoch 4: Loss has been updated.  tensor(989810.248, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 989810.25
# CPU times: user 9h 3min 34s, sys: 5min 45s, total: 9h 9min 19s
# Wall time: 12min 32s

# %%
# %%time
minimizer = SCNMinimizer()
p4 = SCNProtein.from_pkl(path)
loss4, ang4 = minimizer.minimize_scnprotein(p4,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=500,
                            max_eval=500,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.64
# Epoch 0:	69165725356094808.00
# Final loss = 69165725356094808.00
# The protein was not minimized correctly. Lowering LR  to 0.0001 and trying again.
# Starting loss = 1860838086580.56
# Epoch 0:	27100724177123.12
# Final loss = 27100724177123.12
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.60
# Epoch 0:	989810.25
# Epoch 0: Loss has been updated.  tensor(989810.247, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 989810.25
# CPU times: user 18h 40min 47s, sys: 13min 10s, total: 18h 53min 57s
# Wall time: 26min 50s

# %% [markdown]
# # 2000 Total Steps

# %%
# %%time
minimizer = SCNMinimizer()
p6 = SCNProtein.from_pkl(path)
loss6, ang6 = minimizer.minimize_scnprotein(p6,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=400,
                            max_eval=400,
                            epochs=5,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.69
# Epoch 0:	4553811979888351744.00
# Final loss = 4553811979888351744.00
# The protein was not minimized correctly. Lowering LR  to 0.0001 and trying again.
# Starting loss = 1860838086580.54
# Epoch 0:	626831937807137.25
# Final loss = 626831937807137.25
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.59
# Epoch 0:	1365351.56
# Epoch 0: Loss has been updated.  tensor(1365351.560, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 1:	976904.00
# Epoch 1: Loss has been updated.  tensor(976903.999, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 2:	2210105236.47
# Epoch 3:	559034.07
# Epoch 3: Loss has been updated.  tensor(559034.075, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Epoch 4:	474243.30
# Epoch 4: Loss has been updated.  tensor(474243.301, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 474243.30
# CPU times: user 1d 7h 28min 37s, sys: 22min 44s, total: 1d 7h 51min 21s
# Wall time: 44min 17s

# %%
# %%time
minimizer = SCNMinimizer()
p5 = SCNProtein.from_pkl(path)
loss5, ang5 = minimizer.minimize_scnprotein(p5,
                            use_sgd=False,
                            verbose=True,
                            path=None,
                            starting_lr=1e-3,
                            max_iter=2000,
                            max_eval=2000,
                            epochs=1,
                            lr_decay=False)
# Out:
# Starting loss = 1860838086580.52
# Epoch 0:	33578612446485843968.00
# Final loss = 33578612446485843968.00
# The protein was not minimized correctly. Lowering LR  to 0.0001 and trying again.
# Starting loss = 1860838086580.65
# Epoch 0:	139187400023217.70
# Final loss = 139187400023217.70
# The protein was not minimized correctly. Lowering LR  to 1e-05 and trying again.
# Starting loss = 1860838086580.70
# Epoch 0:	31552182528454.25
# Final loss = 31552182528454.25
# The protein was not minimized correctly. Lowering LR  to 1.0000000000000002e-06 and trying again.
# Starting loss = 1860838086580.63
# Epoch 0:	805715.50
# Epoch 0: Loss has been updated.  tensor(805715.499, dtype=torch.float64, grad_fn=<OpenMMEnergyHBackward>)
# Final loss = 805715.50
# CPU times: user 3d 23h 22min 18s, sys: 1h 4min 51s, total: 4d 27min 10s
# Wall time: 2h 13min 9s
