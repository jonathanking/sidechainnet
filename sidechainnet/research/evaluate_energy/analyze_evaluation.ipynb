# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# Failed to connect to the remote Jupyter Server 'http://10.206.1.124:9918/'. Verify the server is running and reachable. (request to http://10.206.1.124:9918/api/kernels?1669834784710 failed, reason: connect ETIMEDOUT 10.206.1.124:9918).

# %%
RESULTS_FILE = "/home/jok120/sidechainnet/sidechainnet/research/evaluate_energy/result07.csv"
df = pd.read_csv(RESULTS_FILE, index_col=0, header=0, na_values=['None']).dropna()
df
# Out:
#                     native     minimized  native_eloss  minimized_eloss  \
# pnid
# 2LQ9_1_A      -2435.029300  -3546.324960  6.339460e+03     -2866.949694
# 2LJV_1_A      -6956.471465  -9770.842029  1.435684e+06     -9385.952099
# 2H8N_1_A     -10254.430226 -13563.967926 -4.185753e+03    -13734.298262
# 2DJQ_1_A      -6841.594967  -6931.925404 -5.739401e+03     -6546.244284
# 1QR8_1_A     -13221.778996 -12509.438033 -8.813457e+03    -11444.512544
# ...                    ...           ...           ...              ...
# 1LD5_1_A      -7241.935467  -8140.681587  8.081748e+03     -8199.570509
# 1WR1_2_B     -11002.617014 -10236.686569 -7.793788e+03     -9926.043624
# 2H7H_3_A      -4122.038642  -6366.628457  3.900753e+02     -6426.024228
# 2N88_1_A      -5719.759447  -5451.596967 -3.360646e+03     -5259.171571
# 2CKA_d2ckaa1  -9875.778495 -11010.666797 -5.920933e+03    -10674.582136
#
#                 af2norelax      af2relax
# pnid
# 2LQ9_1_A      -4584.392486  -7128.398095
# ...

# %% [markdown]
# # Box Plots

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
my_palette = {k: cycle[i] for i, k in enumerate(df.columns)}
my_palette
# Out:
# {'native': '#1f77b4',
#  'minimized': '#ff7f0e',
#  'native_eloss': '#2ca02c',
#  'minimized_eloss': '#d62728',
#  'af2norelax': '#9467bd',
#  'af2relax': '#8c564b'}

# %%
# Plot the results as a box plot, with the energy value on the y axis and the
# structure type on the x axis
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
sns.boxplot(data=df[["native", "minimized", "native_eloss", "minimized_eloss", "af2norelax", "af2relax"]], 
    ax=ax, showfliers=False, palette=my_palette)
ax.set_ylabel("Energy (kJ/mol)")
ax.set_xlabel("Structure type")
ax.set_title("Energy comparison")
# Rotate x labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, horizontalalignment='center')
plt.show()

# %%
# Plot the results as a box plot, with the energy value on the y axis and the
# structure type on the x axis
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
# sns.boxplot(data=df[["native", "minimized", "af2norelax", "af2relax"]], ax=ax, showfliers=False)
sns.boxplot(data=df[["af2norelax", "af2relax"]], ax=ax, showfliers=False, palette=my_palette)
ax.set_ylabel("Energy (kJ/mol)")
ax.set_xlabel("Structure type")
ax.set_title("Energy comparison")
# Rotate x labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, horizontalalignment='center')
plt.show()

# %%
# Plot the results as a box plot, with the energy value on the y axis and the
# structure type on the x axis
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
# sns.boxplot(data=df[["native", "minimized", "af2norelax", "af2relax"]], ax=ax, showfliers=False)
sns.boxplot(data=df[["native", "minimized", "minimized_eloss"]], ax=ax, showfliers=False, palette=my_palette)
ax.set_ylabel("Energy (kJ/mol)")
ax.set_xlabel("Structure type")
ax.set_title("Energy comparison")
# Rotate x labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, horizontalalignment='center')
plt.show()

# %%
df.describe()
# Out:
#              native     minimized  native_eloss  minimized_eloss  \
# count  1.783000e+03  1.783000e+03  1.783000e+03     1.783000e+03
# mean   2.249708e+16  6.672110e+05  4.595335e+15     6.698439e+06
# std    9.499525e+17  2.059138e+07  1.940405e+17     2.332103e+08
# min   -1.583532e+04 -1.870414e+04 -1.426565e+04    -1.916464e+04
# 25%   -8.706080e+03 -9.409068e+03 -4.370349e+03    -8.944826e+03
# 50%   -6.759327e+03 -7.663027e+03 -3.649987e+02    -7.109297e+03
# 75%   -4.467781e+03 -5.704552e+03  1.421553e+04    -5.053536e+03
# max    4.011230e+19  7.801870e+08  8.193475e+18     9.762629e+09
#
#          af2norelax      af2relax
# count  1.783000e+03   1783.000000
# mean   4.626192e+13  -8063.800767
# std    1.704359e+15   3244.401625
# min   -1.194112e+08 -18435.391165
# 25%   -5.283116e+03  -9984.395393
# 50%   -2.646064e+02  -8171.996519
# 75%    1.814547e+04  -6140.590917
# max    7.132219e+16  10710.544943

# %% [markdown]
# # Scatterplots

# %%
# Plot the results as a scatterplot
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(x="native", y="minimized", data=df, ax=ax)
ax.set_xlabel("native energy (kcal/mol)")
ax.set_ylabel("minimized energy (kcal/mol)")
ax.set_title("Energy comparison")
# Set the x and y limits to be the same
if ax.get_xlim() > ax.get_ylim():
    ax.set_ylim(ax.get_xlim())
else:
    ax.set_xlim(ax.get_ylim())
# Draw the diagonal line
ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
plt.show()

# %%
# Plot the results as a scatterplot
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
# Show the correlation between the native and af2norelax energies in a scatterplot
sns.scatterplot(data=df, x="native", y="minimized", ax=ax, s=10)
ax.set_xlabel("Native energy (kcal/mol)")
ax.set_ylabel("minimized energy (kcal/mol)")
ax.set_title("Energy comparison")
# Set the x and y limits to be the same
if ax.get_xlim() > ax.get_ylim():
    ax.set_ylim(ax.get_xlim())
else:
    ax.set_xlim(ax.get_ylim())

ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
plt.show()
