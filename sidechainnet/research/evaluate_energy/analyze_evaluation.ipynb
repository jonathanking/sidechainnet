# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
RESULTS_FILE = "/home/jok120/sidechainnet/sidechainnet/research/evaluate_energy/result04.csv"
df = pd.read_csv(RESULTS_FILE, index_col=0, header=0, na_values=['None']).dropna()
df
# Out:
#                   native    minimized  native_eloss  minimized_eloss  \
# pnid
# 3QO0_3_C      166.757143   -16.105778   1642.918867       -99.692809
# 3N56_2_C      326.942436   600.293904    542.590345       277.113059
# 3N57_2_C     -484.828360  -358.885145   2814.109477     -1069.961195
# 4M38_2_E     -473.652652  -524.382087   -642.966950      -930.054409
# 4BOH_3_M      473.117344   126.882795    127.458331      -332.317553
# ...                  ...          ...           ...              ...
# 2MQK_1_A      209.644935    43.780842  -2806.152072    -10177.040128
# 4V61_47_BZ   2743.997580  3742.537370   3114.092370     49037.547594
# 1YMH_3_E    15722.684944  4849.931045   9764.155440     -5172.064030
# 3A3P_2_B     4172.238187  5399.785342   -521.910940     -4374.234744
# 3G6E_23_V   -2465.484657   252.817183  -4243.986781     -8431.585339
#
#               af2norelax     af2relax
# pnid
# 3QO0_3_C    3.601747e+06   -54.984450
# 3N56_2_C    1.306252e+06   405.910928
# 3N57_2_C    1.479889e+07  -455.433096
# 4M38_2_E    5.349220e+06  -403.451795
# 4BOH_3_M    2.020703e+07   -93.586548
# ...                  ...          ...
# 2MQK_1_A   -1.596821e+03 -1337.773838
# 4V61_47_BZ  2.694771e+03 -2590.417611
# 1YMH_3_E    5.279788e+09  1325.214097
# 3A3P_2_B    2.916922e+03  2103.436286
# 3G6E_23_V   3.990524e+04 -1866.899712
#
# [5824 rows x 6 columns]

# %% [markdown]
# # Box Plots

# %%
# Plot the results as a box plot, with the energy value on the y axis and the
# structure type on the x axis
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
sns.boxplot(data=df[["native", "minimized", "native_eloss", "minimized_eloss", "af2norelax", "af2relax"]], ax=ax, showfliers=False)
ax.set_ylabel("Energy (kcal/mol)")
ax.set_xlabel("Structure type")
ax.set_title("Energy comparison")
# Rotate x labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, horizontalalignment='center')
plt.show()

# %%
# Plot the results as a box plot, with the energy value on the y axis and the
# structure type on the x axis
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
# sns.boxplot(data=df[["native", "minimized", "af2norelax", "af2relax"]], ax=ax, showfliers=False)
sns.boxplot(data=df[["af2norelax", "af2relax"]], ax=ax, showfliers=False)
ax.set_ylabel("Energy (kcal/mol)")
ax.set_xlabel("Structure type")
ax.set_title("Energy comparison")
# Rotate x labels
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, horizontalalignment='center')
plt.show()

# %%
df[["af2norelax", "af2relax"]].describe()
# Out:
#          af2norelax       af2relax
# count  5.824000e+03    5824.000000
# mean   8.020854e+14    1528.993973
# std    5.033968e+16    3872.066720
# min   -7.636031e+03   -7904.650616
# 25%    2.010789e+03     -18.916906
# 50%    4.708409e+03    1325.817310
# 75%    1.181558e+04    2722.579407
# max    3.745250e+18  121728.199501

# %% [markdown]
# # Scatterplots

# %%
# Plot the results as a scatterplot
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
sns.scatterplot(x="native", y="minimized", data=df, ax=ax)
ax.set_xlabel("native energy (kcal/mol)")
ax.set_ylabel("minimized energy (kcal/mol)")
ax.set_title("Energy comparison")
# Set the x and y limits to be the same
if ax.get_xlim() > ax.get_ylim():
    ax.set_ylim(ax.get_xlim())
else:
    ax.set_xlim(ax.get_ylim())
# Draw the diagonal line
ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
plt.show()

# %%
# Plot the results as a scatterplot
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=1.5)
fig, ax = plt.subplots(figsize=(8, 8))
# Show the correlation between the native and af2norelax energies in a scatterplot
sns.scatterplot(data=df, x="native", y="minimized", ax=ax, s=10)
ax.set_xlabel("Native energy (kcal/mol)")
ax.set_ylabel("minimized energy (kcal/mol)")
ax.set_title("Energy comparison")
# Set the x and y limits to be the same
if ax.get_xlim() > ax.get_ylim():
    ax.set_ylim(ax.get_xlim())
else:
    ax.set_xlim(ax.get_ylim())

ax.plot(ax.get_xlim(), ax.get_ylim(), ls="--", c=".3")
plt.show()
